# %%
# 참고 https://www.youtube.com/watch?v=FMKf4rLw1mg&list=PLS8gIc2q83OiamacA4nurGpkeqgQw75xx&index=5
# YOLOv8 Instance Segmentation Tutorial 재학습없이 자기이미지만으로 prediction

# %%
Data Preparation:
MS COCO Dataset으로 사전학습된 YOLOv8 모델을 재학습(Fine Tuning) 하는 경우에는,
Image / Annotation 으로 이루어진 Dataset을 준비해야 한다.
이러한 데이터는 Roboflow(public.roboflow.com)같은
 컴퓨터비전플랫폼에서 제공하는 Training Dataset을 이용하거나,
Labeling과 같은 labeling tool을 이용하여 개발자가 직접 labelling시킨 Image / Annotation 으로 이루어진
Training Dataset을 구축해야 한다.

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 607.6/607.6 kB 6.0 MB/s eta 0:00:00
# ...

# %%
# !pip install tensorflow

# %%
import os
import zipfile

with zipfile.ZipFile('/content/test_image_dir.zip') as target_file:
  target_file.extractall('/content/test_image_dir')

print('test images = ', os.listdir('/content/test_image_dir'))
# Out:
# test images =  ['test1.jpg', 'test2.jpg', 'test3.jpg', 'test4.jpg']

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
import os
# runs/detect/predict2 예측이미지
runurl = '/content/test_image_dir'
runurllist = os.listdir(runurl) # 변경된이미지들을 리스트화

predict_array_list = []
for i in range(len(runurllist)):
  loaded_img = load_img(os.path.join(runurl, runurllist[i]), target_size=(100, 100))
  #loaded_img = load_img(runurllist[i], target_size=(300, 300))
  loaded_img_array = img_to_array(loaded_img) / 255.0

  predict_array_list.append(loaded_img_array)

plt.figure(figsize = (100, 100))

# for i in range(len(img_array_list)): range() 함수는 함수의 전달인자에 기반하여 정수 순열을 제공합니다
# for i in range(len(predict_array_list[10])):  # 10번째 이미지까지만 출력되게
for i in range(4):  # 10번째 이미지까지만 출력되게
  #plt.subplot(1, len(predict_array_list[10]), i+1)
  plt.subplot(2, 2, i+1) # 2개씩해서 5줄은?
  #plt.subplot(총 행 개수, 총 열 개수, 그래프 번호) https://heytech.tistory.com/448
  plt.xticks([]); plt.yticks([])
  plt.title(predict_array_list[i]) # 목록 인덱스가 범위를 벗어남??
  plt.imshow(predict_array_list[i])

# %%
import ultralytics

# %%
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.141 🚀 Python-3.10.6 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.3/107.7 GB disk)

# %%
from ultralytics import YOLO

model = YOLO('yolov8n-seg.pt') # 그외 yolov8m-seg, yolov8l-seg, yolov8x-seg 등이 있음
# Out:
# ...
# 100%|██████████| 6.73M/6.73M [00:00<00:00, 62.6MB/s]

# %%
print(type(model.names), len(model.names))

print(model.names)
# Out:
# <class 'dict'> 80
# ...

# %%
results = model.predict(source = '/content/test_image_dir/*.jpg', save=True)
# Out:
# image 1/4 /content/test_image_dir/test1.jpg: 640x640 1 airplane, 503.8ms
# image 2/4 /content/test_image_dir/test2.jpg: 640x640 2 bears, 355.7ms
# image 3/4 /content/test_image_dir/test3.jpg: 640x640 2 oranges, 340.0ms
# image 4/4 /content/test_image_dir/test4.jpg: 640x640 1 cup, 2 spoons, 5 bowls, 1 sandwich, 1 dining table, 344.7ms
# Speed: 10.6ms preprocess, 386.0ms inference, 23.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/segment/predict

# %%
# !pip install tensorflow

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
runurl = '/content/runs/segment/predict/'
runurllist = os.listdir(runurl)
img_array_list = []
img_names = ['test1.jpg', 'test2.jpg', 'test3.jpg', 'test4.jpg']

for i in range(len(runurllist)):
  loaded_img = load_img(os.path.join(runurl, img_names[i]), target_size=(300, 300))

  loaded_img_array = img_to_array(loaded_img) / 255.0

  img_array_list.append(loaded_img_array)

plt.figure(figsize = (300, 300))

for i in range(len(img_array_list)):
  plt.subplot(1, len(img_array_list), i+1)
  plt.xticks([]); plt.yticks([])
  plt.title(img_names[i])
  plt.imshow(img_array_list[i])

# %%
import numpy as np

for result in results:

  uniq, cnt = np.unique(result.boxes.cls.cpu().numpy(), return_counts=True)
  uniq_cnt_dict = dict(zip(uniq, cnt))

  print('\n{class num:counts} =', uniq_cnt_dict, '\n')

  for c in result.boxes.cls:
    print('class num =', int(c), ', class_name=', model.names[int(c)])
# Out:
# {class num:counts} = {4.0: 1}
#
# class num = 4 , class_name= airplane
#
# {class num:counts} = {21.0: 2}
#
# class num = 21 , class_name= bear
# class num = 21 , class_name= bear
#
# {class num:counts} = {49.0: 2}
#
# class num = 49 , class_name= orange
# class num = 49 , class_name= orange
#
# {class num:counts} = {41.0: 1, 44.0: 2, 45.0: 5, 48.0: 1, 60.0: 1}
#
# class num = 45 , class_name= bowl
# class num = 45 , class_name= bowl
# class num = 45 , class_name= bowl
# class num = 44 , class_name= spoon
# class num = 60 , class_name= dining table
# class num = 41 , class_name= cup
# class num = 44 , class_name= spoon
# class num = 48 , class_name= sandwich
# class num = 45 , class_name= bowl
# class num = 45 , class_name= bowl

# %%
# YOLOv8n버전모델이다보니, 1,2번 이미지에선 오류가 있음.
